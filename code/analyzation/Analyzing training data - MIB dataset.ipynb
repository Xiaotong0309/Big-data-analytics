# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
from sklearn.model_selection import  train_test_split
from sklearn.preprocessing import LabelBinarizer, StandardScaler
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.svm import SVC
import matplotlib
import matplotlib.pyplot as plt
import itertools

# %%
names = ['has_banner','has_location','has_extended_profile','has_url','followers','friends','num_posts','has_duplicate','onlyHasURL','has_retweet','contains_hashTag','label']
data_public = pd.read_csv("tweet_public.csv",names = names)

names1 = ['has_banner','has_location','has_extended_profile','has_url','followers','friends','label']
data_private = pd.read_csv("user_all.csv",names = names1)

# %%
fake_followers_public = len(data_public.query('label == "0"'))
genuine_followers_public = len(data_public.query('label == "1"'))

fake_followers_private = len(data_private.query('label == "0"'))
genuine_followers_private = len(data_private.query('label == "1"'))

print(fake_followers_public)
print(genuine_followers_public)

print(fake_followers_private)
print(genuine_followers_private)
# Out:
# 1117
# 1083
# 3351
# 3474

# %%
public_fake = data_public.query('label == "0"')
public_real = data_public.query('label == "1"')

private_fake = data_private.query('label == "0"')
private_real = data_private.query('label == "1"')

# %% [markdown]
# # Histogram analysis

# %%
public_fake.hist(figsize=(20,15))
public_real.hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1cfb9470>,
# ...
#       dtype=object)

# %%
private_fake.hist(figsize=(20,15))
private_real.hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e973a90>,
# ...
#       dtype=object)
